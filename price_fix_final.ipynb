# %% [markdown]
# <a href="https://colab.research.google.com/github/Pathway2008/CarPrice/blob/main/price_fix_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for n in range(110,111):
  costs = {
    99: 4000,
    100: 5400,
    101: 6500,
    102: 9500,
    103: 9500,
    104: 14000,
    105: 300,
    106: 500,
    107: 640,
    108: 1650,
    109: 2500,
    110: 4700,
    111: 8200,
    112: 16000,
    113: 30000,
    114: 47000,
    115: 68000,
    116: 130000,
    117: 170000
}
  probabilities = {
      n+3: 1.0,
      n+2: 0.8996,
      n+1: 0.6705,
      n+0: 0.5,
      n-1: 0.373,
      n-2: 0.2783,
      n-3: 0.2078,
      n-4: 0.1552,
      n-5: 0.1159,
      n-6: 0.0866,
      n-7: 0.0648,
      n-8: 0.0485,
      n-9: 0.0363,
      n-10: 0.0271
}
  probabilities3 = {
      n+5 : 1*0.81,
      n+4 : 0.8058*0.81,
      n+3 : 0.6002*0.81,
      n+2 : 0.4472*0.81,
      n+1 : 0.3333*0.81,
      n+0 : 0.2486*0.81,
      n-1 : 0.1854*0.81,
      n-2 : 0.1384*0.81,
      n-3 : 0.1033*0.81,
      n-4 : 0.0771*0.81,
      n-5 : 0.0576*0.81,
      n-6 : 0.0431*0.81,
      n-7 : 0.0322*0.81,
      n-8 : 0.0241*0.81,
      n-9 : 0.018*0.81,
      n-10 : 0.0135*0.81
}

  probabilities4 = {
      n+7: 1*0.64,
      n+6: 0.8129*0.64,
      n+5: 0.6050*0.64,
      n+4: 0.4505*0.64,
      n+3: 0.3355*0.64,
      n+2: 0.25*0.64,
      n+1: 0.1863*0.64,
      n+0: 0.139*0.64,
      n-1: 0.1037*0.64,
      n-2: 0.0773*0.64,
      n-3: 0.0577*0.64,
      n-4: 0.0431*0.64,
      n-5: 0.0322*0.64,
      n-6: 0.0241*0.64,
      n-7: 0.018*0.64,
      n-8: 0.0135*0.64
}

  probabilities5 = {
      n+7: 0.4816*0.5,
      n+6: 0.3614*0.5,
      n+5: 0.2688*0.5,
      n+4: 0.2*0.5,
      n+3: 0.1489*0.5,
      n+2: 0.1108*0.5,
      n+1: 0.0826*0.5,
      n+0: 0.0615*0.5,
      n-1: 0.0458*0.5,
      n-2: 0.0342*0.5,
      n-3: 0.0255*0.5,
      n-4: 0.019*0.5,
      n-5: 0.0142*0.5,
      n-6: 0.0106*0.5,
      n-7: 0.0078*0.5,
      n-8: 0.0059*0.5
}

  costs_list = list(costs.items())
  probabilities_list = list(probabilities.items())
  probabilities3_list = list(probabilities3.items())
  probabilities4_list = list(probabilities4.items())
  probabilities5_list = list(probabilities5.items())


  results = []
  for i in range(len(costs_list)):
      for j in range(len(probabilities_list)):
          if costs_list[i][0] == probabilities_list[j][0]:
              per_cost = costs_list[i][1] / probabilities_list[j][1]
              results.append((costs_list[i][0], costs_list[i][1],probabilities_list[j][1], per_cost))
          else:
            pass
  sorted_results = sorted(results, key=lambda x: x[3])


  results3 = []
  for i in range(len(costs_list)):
      for j in range(len(probabilities3_list)):
          if costs_list[i][0] == probabilities3_list[j][0]:
              per_cost = costs_list[i][1] / probabilities3_list[j][1]
              results3.append((costs_list[i][0], costs_list[i][1], probabilities3_list[j][1], per_cost))
          else:
              pass


  sorted_results3 = sorted(results3, key=lambda x: x[3])


  results4 = []
  for i in range(len(costs_list)):
      for j in range(len(probabilities4_list)):
          if costs_list[i][0] == probabilities4_list[j][0]:
              per_cost = costs_list[i][1] / probabilities4_list[j][1]
              results4.append((costs_list[i][0], costs_list[i][1], probabilities4_list[j][1], per_cost))
          else:
              pass

  sorted_results4 = sorted(results4, key=lambda x: x[3])


  results5 = []
  for i in range(len(costs_list)):
      for j in range(len(probabilities5_list)):
          if costs_list[i][0] == probabilities5_list[j][0]:
              per_cost = costs_list[i][1] / probabilities5_list[j][1]
              results5.append((costs_list[i][0], costs_list[i][1], probabilities5_list[j][1], per_cost))
          else:
              pass

  sorted_results5 = sorted(results5, key=lambda x: x[3])

# %%
import itertools

numbers = [1, 2, 3, 4, 5, 6]  # Replace with your desired numbers

combinations = []

for length in range(1, len(numbers) + 1):
    for combo in itertools.product(numbers, repeat=length):
        combinations.append(combo)

for combo in combinations:
    result = '+'.join(map(str, combo))
    total = sum(combo)
    print(f"{result} = {total}")

# %%
import itertools
numbers = ['a', 'b', 'c', 'd', 'e','f']

combinations = []

for length in range(1, 6):
    for combo in itertools.product(numbers, repeat=length):
        combinations.append(combo)

for combo in combinations:
    result = '+'.join(combo)
    print(result)

# %%
sorted_results , len(sorted_results)
# Out:
# ([(105, 300, 0.1159, 2588.4383088869713),
#   (107, 640, 0.2078, 3079.8845043310876),
#   (106, 500, 0.1552, 3221.6494845360826),
#   (108, 1650, 0.2783, 5928.853754940712),
#   (109, 2500, 0.373, 6702.412868632708),
#   (110, 4700, 0.5, 9400.0),
#   (111, 8200, 0.6705, 12229.679343773303),
#   (112, 16000, 0.8996, 17785.68252556692),
#   (113, 30000, 1.0, 30000.0),
#   (103, 9500, 0.0648, 146604.93827160494),
#   (104, 14000, 0.0866, 161662.81755196306),
#   (101, 6500, 0.0363, 179063.3608815427),
#   (102, 9500, 0.0485, 195876.28865979382),
#   (100, 5400, 0.0271, 199261.9926199262)],
#  14)

# %%
results
# Out:
# [(100, 5400, 0.0271, 199261.9926199262),
#  (101, 6500, 0.0363, 179063.3608815427),
#  (102, 9500, 0.0485, 195876.28865979382),
#  (103, 9500, 0.0648, 146604.93827160494),
#  (104, 14000, 0.0866, 161662.81755196306),
#  (105, 300, 0.1159, 2588.4383088869713),
#  (106, 500, 0.1552, 3221.6494845360826),
#  (107, 640, 0.2078, 3079.8845043310876),
#  (108, 1650, 0.2783, 5928.853754940712),
#  (109, 2500, 0.373, 6702.412868632708),
#  (110, 4700, 0.5, 9400.0),
#  (111, 8200, 0.6705, 12229.679343773303),
#  (112, 16000, 0.8996, 17785.68252556692),
#  (113, 30000, 1.0, 30000.0)]

# %%
sorted_results3
# Out:
# [(105, 300, 0.046656, 6430.041152263374),
#  (107, 640, 0.08367300000000001, 7648.823395838561),
#  (106, 500, 0.062451000000000007, 8006.276921106147),
#  (108, 1650, 0.11210400000000001, 14718.47570113466),
#  (109, 2500, 0.15017400000000003, 16647.355734015207),
#  (110, 4700, 0.201366, 23340.583812560217),
#  (111, 8200, 0.269973, 30373.40771114148),
#  (112, 16000, 0.362232, 44170.58680624572),
#  (113, 30000, 0.486162, 61707.825786466245),
#  (114, 47000, 0.652698, 72008.80039466951),
#  (115, 68000, 0.81, 83950.61728395062),
#  (103, 9500, 0.026082, 364235.8714822483),
#  (104, 14000, 0.034911000000000005, 401019.7358998596),
#  (101, 6500, 0.01458, 445816.18655692734),
#  (102, 9500, 0.019521, 486655.3967522156),
#  (100, 5400, 0.010935, 493827.16049382713)]

# %%
cost2 = []
for i in range(len(sorted_results)):
  A = sorted_results[i][1]
  p = sorted_results[i][2]
  cost = A/p
  cost2.append((round(cost), sorted_results[i][0], sorted_results[i][1], sorted_results[i][2]))

# %%
cost2 = sorted(cost2, key=lambda x: x[0])
cost2
# Out:
# [(2588, 105, 300, 0.1159),
#  (3080, 107, 640, 0.2078),
#  (3222, 106, 500, 0.1552),
#  (5929, 108, 1650, 0.2783),
#  (6702, 109, 2500, 0.373),
#  (9400, 110, 4700, 0.5),
#  (12230, 111, 8200, 0.6705),
#  (17786, 112, 16000, 0.8996),
#  (30000, 113, 30000, 1.0),
#  (146605, 103, 9500, 0.0648),
#  (161663, 104, 14000, 0.0866),
#  (179063, 101, 6500, 0.0363),
#  (195876, 102, 9500, 0.0485),
#  (199262, 100, 5400, 0.0271)]

# %%
cost3 = []
for i in range(len(sorted_results)):
  A = sorted_results[i][1]
  p = sorted_results[i][2]
  for j in range(len(sorted_results3)):
    B = sorted_results3[j][1]
    q = sorted_results3[j][2]
    cost = (1/(p*q)) * ((1-p)*A +p*(1-q)*(A+B) + p*q*(A+B))
    cost3.append((round(cost),sorted_results[i][0], sorted_results[i][1], sorted_results[i][2], sorted_results3[j][0] ,sorted_results3[j][1],  sorted_results3[j][2]))

# %%
p=0.1159*5
q=0.150174*5
A=300*5
B=2500*5
(1/(p*q)) * ((1-p)*A +p*(1-q)*(A+B) + p*q*(A+B))
#개수가 달리지면 값이 달라짐
# Out:
# 20094.60799990274

# %%
cost3 = sorted(cost3, key=lambda x: x[0])
cost3
# Out:
# [(33884, 105, 300, 0.1159, 109, 2500, 0.15017400000000003),
#  (36195, 105, 300, 0.1159, 110, 4700, 0.201366),
#  (37156, 107, 640, 0.2078, 109, 2500, 0.15017400000000003),
#  (37808, 105, 300, 0.1159, 108, 1650, 0.11210400000000001),
#  (38100, 106, 500, 0.1552, 109, 2500, 0.15017400000000003),
#  (38584, 105, 300, 0.1159, 107, 640, 0.08367300000000001),
#  (282327, 113, 30000, 1.0, 108, 1650, 0.11210400000000001),
#  (283534, 104, 14000, 0.0866, 115, 68000, 0.81),
#  (292800, 112, 16000, 0.8996, 106, 500, 0.062451000000000007),
#  (296623, 103, 9500, 0.0648, 114, 47000, 0.652698),
#  (305016, 101, 6500, 0.0363, 115, 68000, 0.81),
#  (319693, 104, 14000, 0.0866, 114, 47000, 0.652698),
#  (325773, 102, 9500, 0.0485, 115, 68000, 0.81),
#  (329953, 100, 5400, 0.0271, 115, 68000, 0.81),
#  (346352, 101, 6500, 0.0363, 114, 47000, 0.652698),
#  (363264, 103, 9500, 0.0648, 113, 30000, 0.486162),
#  (366187, 113, 30000, 1.0, 107, 640, 0.08367300000000001),
#  (372111, 102, 9500, 0.0485, 114, 47000, 0.652698),
#  (377299, 100, 5400, 0.0271, 114, 47000, 0.652698),
#  (387639, 112, 16000, 0.8996, 105, 300, 0.046656),
#  (394237, 104, 14000, 0.0866, 113, 30000, 0.486162),
#  (430028, 101, 6500, 0.0363, 113, 30000, 0.486162),
#  (448897, 103, 9500, 0.0648, 112, 16000, 0.362232),
#  (463478, 105, 300, 0.1159, 103, 9500, 0.026082),
#  (464611, 102, 9500, 0.0485, 113, 30000, 0.486162),
#  (471575, 100, 5400, 0.0271, 113, 30000, 0.486162),
#  (475164, 105, 300, 0.1159, 104, 14000, 0.034911000000000005),
#  (482321, 107, 640, 0.2078, 103, 9500, 0.026082),
#  (487756, 106, 500, 0.1552, 103, 9500, 0.026082),
#  (488383, 113, 30000, 1.0, 106, 500, 0.062451000000000007),
#  (489241, 107, 640, 0.2078, 104, 14000, 0.034911000000000005),
#  (490467, 104, 14000, 0.0866, 112, 16000, 0.362232),
#  (493302, 106, 500, 0.1552, 104, 14000, 0.034911000000000005),
#  (538504, 101, 6500, 0.0363, 112, 16000, 0.362232),
#  (570847, 108, 1650, 0.2783, 104, 14000, 0.034911000000000005),
#  (573409, 103, 9500, 0.0648, 111, 8200, 0.269973),
#  (584919, 102, 9500, 0.0485, 112, 16000, 0.362232),
#  (591552, 108, 1650, 0.2783, 103, 9500, 0.026082),
#  (593005, 109, 2500, 0.373, 104, 14000, 0.034911000000000005),
#  (594266, 100, 5400, 0.0271, 112, 16000, 0.362232),
#  (619253, 105, 300, 0.1159, 102, 9500, 0.019521),
#  (621211, 109, 2500, 0.373, 103, 9500, 0.026082),
#  (623350, 105, 300, 0.1159, 101, 6500, 0.01458),
#  (629184, 104, 14000, 0.0866, 111, 8200, 0.269973),
#  (644428, 107, 640, 0.2078, 102, 9500, 0.019521),
#  (649434, 113, 30000, 1.0, 105, 300, 0.046656),
#  (651690, 106, 500, 0.1552, 102, 9500, 0.019521),
#  (657057, 107, 640, 0.2078, 101, 6500, 0.01458),
#  (666780, 106, 500, 0.1552, 101, 6500, 0.01458),
#  (670276, 110, 4700, 0.5, 104, 14000, 0.034911000000000005),
#  (693637, 101, 6500, 0.0363, 111, 8200, 0.269973),
#  (1939727, 104, 14000, 0.0866, 107, 640, 0.08367300000000001),
#  (2023462, 113, 30000, 1.0, 102, 9500, 0.019521),
#  (2120318, 112, 16000, 0.8996, 100, 5400, 0.010935),
#  (2147686, 101, 6500, 0.0363, 107, 640, 0.08367300000000001),
#  (2348622, 102, 9500, 0.0485, 107, 640, 0.08367300000000001),
#  (2355526, 103, 9500, 0.0648, 106, 500, 0.062451000000000007),
#  (2389086, 100, 5400, 0.0271, 107, 640, 0.08367300000000001),
#  (2503429, 113, 30000, 1.0, 101, 6500, 0.01458),
#  (2596641, 104, 14000, 0.0866, 106, 500, 0.062451000000000007),
#  (2875268, 101, 6500, 0.0363, 106, 500, 0.062451000000000007),
#  (3144486, 102, 9500, 0.0485, 106, 500, 0.062451000000000007),
#  (3148683, 103, 9500, 0.0648, 105, 300, 0.046656),
#  (3198700, 100, 5400, 0.0271, 106, 500, 0.062451000000000007),
#  (3237311, 113, 30000, 1.0, 100, 5400, 0.010935),
#  (3471425, 104, 14000, 0.0866, 105, 300, 0.046656),
#  (3844379, 101, 6500, 0.0363, 105, 300, 0.046656),
#  (4204739, 102, 9500, 0.0485, 105, 300, 0.046656),
#  (4277306, 100, 5400, 0.0271, 105, 300, 0.046656),
#  (4600411, 103, 9500, 0.0648, 104, 14000, 0.034911000000000005),
#  (5031733, 104, 14000, 0.0866, 104, 14000, 0.034911000000000005),
#  (5530158, 101, 6500, 0.0363, 104, 14000, 0.034911000000000005),
#  (5985160, 103, 9500, 0.0648, 103, 9500, 0.026082),
#  (6011752, 102, 9500, 0.0485, 104, 14000, 0.034911000000000005),
#  (6108733, 100, 5400, 0.0271, 104, 14000, 0.034911000000000005),
#  (6562488, 104, 14000, 0.0866, 103, 9500, 0.026082),
#  (7229636, 101, 6500, 0.0363, 103, 9500, 0.026082),
#  (7874254, 102, 9500, 0.0485, 103, 9500, 0.026082),
#  (7996770, 103, 9500, 0.0648, 102, 9500, 0.019521),
#  (8004064, 100, 5400, 0.0271, 103, 9500, 0.026082),
#  (8768138, 104, 14000, 0.0866, 102, 9500, 0.019521),
#  (9659513, 101, 6500, 0.0363, 102, 9500, 0.019521),
#  (10501025, 103, 9500, 0.0648, 101, 6500, 0.01458),
#  (10520787, 102, 9500, 0.0485, 102, 9500, 0.019521),
#  (10694226, 100, 5400, 0.0271, 102, 9500, 0.019521),
#  (11533801, 104, 14000, 0.0866, 101, 6500, 0.01458),
#  (12727254, 101, 6500, 0.0363, 101, 6500, 0.01458),
#  (13880404, 102, 9500, 0.0485, 101, 6500, 0.01458),
#  (13900772, 103, 9500, 0.0648, 100, 5400, 0.010935),
#  (14112620, 100, 5400, 0.0271, 101, 6500, 0.01458),
#  (15277807, 104, 14000, 0.0866, 100, 5400, 0.010935),
#  (16869077, 101, 6500, 0.0363, 100, 5400, 0.010935),
#  (18406611, 102, 9500, 0.0485, 100, 5400, 0.010935),
#  (18716232, 100, 5400, 0.0271, 100, 5400, 0.010935)]

# %%
cost4 = []
for i in range(len(sorted_results)):
  A = sorted_results[i][1]
  p = sorted_results[i][2]
  for j in range(len(sorted_results3)):
    B = sorted_results3[j][1]
    q = sorted_results3[j][2]
    for w in range(len(sorted_results4)):
      C = sorted_results4[w][1]
      r = sorted_results4[w][2]
      cost = (1/(p*q*r))*((1-p)*A + p*(1-q)*(A+B) + p*q*(1-r)*0.65*(A+B+C) + p*q*(1-r)*0.35*(B+C) + p*q*r*(A+B+C))
      cost4.append((round(cost),sorted_results[i][0], sorted_results[i][1], sorted_results[i][2],
                    sorted_results3[j][0] ,sorted_results3[j][1],  sorted_results3[j][2],
                    sorted_results4[w][0], sorted_results4[w][1], sorted_results4[w][2]))

# %%
cost4 = sorted(cost4, key=lambda x: x[0])
cost4[0]
# Out:
# (172923, 105, 300, 0.1552, 109, 2500, 0.201366, 115, 68000, 0.5202559999999999)

# %%
cost5 = []
for i in range(len(sorted_results)):
  A = sorted_results[i][1]
  p = sorted_results[i][2]
  for j in range(len(sorted_results3)):
    B = sorted_results3[j][1]
    q = sorted_results3[j][2]
    for w in range(len(sorted_results4)):
      C = sorted_results4[w][1]
      r = sorted_results4[w][2]
      for y in range(len(sorted_results5)):
        D = sorted_results5[y][1]
        t = sorted_results5[y][2]
        cost = (1/(p*q*r*t))*((1-p)*A + p*(1-q)*(A+B) + p*q*(1-r)*0.65*(A+B+C) + p*q*(1-r)*0.35*(B+C)
                  + p*q*r*(1-t)*0.55*(A+B+C+D) + p*q*r*(1-t)*0.45*(A+B+C+D)+p*q*r*t*(A+B+C+D))
        cost5.append((round(cost),sorted_results[i][0], sorted_results[i][1], sorted_results[i][2],
                      sorted_results3[j][0] ,sorted_results3[j][1],  sorted_results3[j][2],
                      sorted_results4[w][0], sorted_results4[w][1], sorted_results4[w][2],
                      sorted_results5[y][0],sorted_results5[y][1],sorted_results5[y][2]))

# %%
cost5 = sorted(cost5, key=lambda x: x[0])
cost5[0]
# Out:
# (1257986,
#  105,
#  300,
#  0.1552,
#  109,
#  2500,
#  0.201366,
#  115,
#  68000,
#  0.5202559999999999,
#  116,
#  130000,
#  0.2408)

# %%
sorted_results
# Out:
# [(105, 300, 0.1552, 1932.9896907216494),
#  (107, 640, 0.2783, 2299.676607977003),
#  (106, 500, 0.2078, 2406.159769008662),
#  (108, 1650, 0.373, 4423.592493297587),
#  (109, 2500, 0.5, 5000.0),
#  (110, 4700, 0.6705, 7009.694258016406),
#  (111, 8200, 0.8996, 9115.162294353046),
#  (112, 16000, 1.0, 16000.0),
#  (103, 9500, 0.0866, 109699.7690531178),
#  (104, 14000, 0.1159, 120793.78774805866),
#  (101, 6500, 0.0485, 134020.61855670103),
#  (102, 9500, 0.0648, 146604.93827160494),
#  (99, 4000, 0.0271, 147601.47601476015),
#  (100, 5400, 0.0363, 148760.3305785124)]
